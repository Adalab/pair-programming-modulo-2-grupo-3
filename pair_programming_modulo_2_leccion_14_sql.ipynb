# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# ...
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.4 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 29.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)

# %%
driver = webdriver.Chrome()

# 2. Metemos la URL
driver.get("https://www.casadellibro.com/")
sleep(5)
driver.maximize_window()
sleep(5)

driver.find_element("css selector", "#onetrust-accept-btn-handler").click()

driver.find_element("css selector", "#m-c > div:nth-child(2) > a").click()       # entro en categoria ficcion #
sleep(5)
diccionario_resultados = {"nombre": []}
for i in range(1,20):
    try:
        driver.find_element("css selector" , f"#l-p-c > div:nth-child({i}) > a > div > cdl-img > img").click()         # entro en el libro #
        sleep(5)
        nombre = driver.find_element("xpath", '//*[@id="t-p-f"]').text
        diccionario_resultados["nombre"].append(nombre)                        # escribir nombre #


    except Exception as e:
        # En caso de error, agregar valores predeterminados para esta iteración
        print(f"Error en el producto {i}: {e}")
        diccionario_resultados["nombre"].append("No info")

driver.close()

# Mostrar resultados
print(diccionario_resultados)
# Out:
# Error en el producto 1: Message: element click intercepted: Element <img src="https://imagessl2.casadellibro.com/a/l/s5/92/9788408299592.webp" sizes="190px" srcset="https://imagessl2.casadellibro.com/a/l/s4/92/9788408299592.webp 39w, https://imagessl2.casadellibro.com/a/l/s6/92/9788408299592.webp 65w, https://imagessl2.casadellibro.com/a/l/s3/92/9788408299592.webp 75w, https://imagessl2.casadellibro.com/a/l/s2/92/9788408299592.webp 117w, https://imagessl2.casadellibro.com/a/l/s1/92/9788408299592.webp 143w, https://imagessl2.casadellibro.com/a/l/s5/92/9788408299592.webp 229w, https://imagessl2.casadellibro.com/a/l/s7/92/9788408299592.webp 552w" alt="por si un dia volvemos-maria dueñas-9788408299592" width="229" height="334" loading="lazy" class="svelte-k5yotb"> is not clickable at point (569, 532). Other element would receive the click: <div id="m-c-f[1]" class="floating-menu border svelte-1qiif35">...</div>
#   (Session info: chrome=135.0.7049.84)
# Stacktrace:
# ...
